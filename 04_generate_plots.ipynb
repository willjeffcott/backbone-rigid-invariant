# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tqdm
from scipy.spatial import KDTree
import ast
import seaborn as sns
import time
import os
from multiprocessing import Pool
import requests
import ast
from matplotlib.colors import LogNorm
import pickle
import scipy.sparse as sp
from scipy.signal import convolve2d

# %%
os.chdir('/content/drive/MyDrive/BRI Analysis')

# %% [markdown]
# ### Now do some plotting

# %%
# %run hist_functions.py
# %run plot_functions.py

# %%
# Get data
inv_dir = "./data/bri_computations"
invariant_batches = os.listdir(inv_dir)

restrict = False
mean = True

histograms_list = read_data([i.split('.')[0] for i in invariant_batches], restrict, mean)

if not(restrict) and not(mean):
    restrict_suffix = ""
    mean_suffix = ""
elif not(restrict) and mean:
    restrict_suffix = ""
    mean_suffix = "_mean"
elif restrict and not(mean):
    restrict_suffix = "_restrict"
    mean_suffix = ""
else:
    restrict_suffix = "_restrict"
    mean_suffix = "_mean"

output_folder_heatmaps = f"./plotting/heatmaps{mean_suffix}{restrict_suffix}/"
output_folder_heatmaps_log = f"./plotting/heatmaps_log{mean_suffix}{restrict_suffix}/"
output_folder_grid = f"./plotting/grid_heatmaps{mean_suffix}{restrict_suffix}/"
output_folder_grid_log = f"./plotting/grid_heatmaps_log{mean_suffix}{restrict_suffix}/"
output_folder_histograms = f"./plotting/histograms{mean_suffix}{restrict_suffix}/"
output_folder_histograms_log = f"./plotting/histograms_log{mean_suffix}{restrict_suffix}/"


if not os.path.exists(output_folder_heatmaps):
  os.makedirs(output_folder_heatmaps)

if not os.path.exists(output_folder_heatmaps_log):
  os.makedirs(output_folder_heatmaps_log)

if not os.path.exists(output_folder_grid):
  os.makedirs(output_folder_grid)

if not os.path.exists(output_folder_grid_log):
  os.makedirs(output_folder_grid_log)

if not os.path.exists(output_folder_histograms):
  os.makedirs(output_folder_histograms)

if not os.path.exists(output_folder_histograms_log):
  os.makedirs(output_folder_histograms_log)
# Out:
# 100%|██████████| 118/118 [00:06<00:00, 18.63it/s]

# %% [markdown]
# ### Standard heatmaps

# %%
plot_heatmaps(histograms_list[0],range(9),invariant='AL',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=False)
plot_heatmaps(histograms_list[0],range(6,9),invariant='AL',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=True)
plot_heatmaps(histograms_list[1],range(9),invariant='BRI',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=False)
plot_heatmaps(histograms_list[2],range(3),invariant='TRIN',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-165050161.py in <cell line: 0>()
# ----> 1 plot_heatmaps(histograms_list[0],range(9),invariant='AL',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=False)
#       2 plot_heatmaps(histograms_list[0],range(6,9),invariant='AL',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=True)
#       3 plot_heatmaps(histograms_list[1],range(9),invariant='BRI',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=False)
#       4 plot_heatmaps(histograms_list[2],range(3),invariant='TRIN',output_folder=output_folder_heatmaps,output_folder_log=output_folder_heatmaps_log,shift=False)
#
# ...

# %% [markdown]
# ### Grid heatmaps

# %%
if not(mean): #heatmaps differentiated by residue don't make sense with mean
  run_heatmap_grid(histograms_list[0],range(9),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='AL',shift=False)
  run_heatmap_grid(histograms_list[0],range(6,9),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='AL',shift=True)
  run_heatmap_grid(histograms_list[1],range(9),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='BRI',shift=False)
  run_heatmap_grid(histograms_list[2],range(3),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='TRIN',shift=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1088989571.py in <cell line: 0>()
#       1 #run_heatmap_grid(histograms_list[0],range(9),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='AL',shift=False)
# ----> 2 run_heatmap_grid(histograms_list[0],range(6,9),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='AL',shift=True)
#       3 run_heatmap_grid(histograms_list[1],range(9),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='BRI',shift=False)
#       4 run_heatmap_grid(histograms_list[2],range(3),output_folder=output_folder_grid,output_folder_log=output_folder_grid_log,invariant='TRIN',shift=False)
#
# /content/drive/MyDrive/BRI Analysis/plot_functions.py in run_heatmap_grid(histograms, idx, output_folder, output_folder_log, invariant, shift)
# ...

# %% [markdown]
# ### Plot histograms

# %%
plot_histograms(histograms_list[0],range(9),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='AL',shift=False)
plot_histograms(histograms_list[0],range(6,9),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='AL',shift=True)
plot_histograms(histograms_list[1],range(9),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='BRI',shift=False)
plot_histograms(histograms_list[2],range(3),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='TRIN',shift=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-226147888.py in <cell line: 0>()
#       1 plot_histograms(histograms_list[0],range(9),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='AL',shift=False)
# ----> 2 plot_histograms(histograms_list[0],range(6,9),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='AL',shift=True)
#       3 plot_histograms(histograms_list[1],range(9),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='BRI',shift=False)
#       4 plot_histograms(histograms_list[2],range(3),output_folder=output_folder_histograms,output_folder_log=output_folder_histograms_log,invariant='TRIN',shift=False)
#
# ...
